# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.

# Seu código aqui

url = ('https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl')

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
#verificando o conteúdo do arquivo

r.json()
# Out:
# {'items': [{'id_pleito': 6963,
#    'tipo_interessado': 'Município',
#    'interessado': 'Novo Repartimento',
#    'cod_ibge': 1505064,
#    'uf': 'PA',
#    'num_pvl': None,
#    'status': 'Deferido',
#    'num_processo': '17944.000468/2004-89',
#    'data_protocolo': '2004-09-03T03:00:00Z',
#    'tipo_operacao': 'Operação contratual interna',
#    'finalidade': 'Saneamento básico',
#    'tipo_credor': 'Instituição Financeira Nacional',
#    'credor': 'Caixa Econômica Federal',
#    'moeda': 'Real',
#    'valor': 13500000,
#    'pvl_assoc_divida': 0,
#    'pvl_contradado_credor': 0,
#    'data_status': '13/10/2004'},
#   {'id_pleito': 7636,
#    'tipo_interessado': 'Município',
#    'interessado': 'Ramilândia',
#    'cod_ibge': 4121257,
#    'uf': 'PR',
#    'num_pvl': None,
#    'status': 'Deferido',
#    'num_processo': '17944.000624/2012-11',
#    'data_protocolo': '2012-04-23T03:00:00Z',
#    'tipo_operacao': 'Operação contratual interna',
#    'finalidade': 'Infraestrutura',
# ...

# %%
data_json = r.json()
print(data_json['items'])
# Out:
# [{'id_pleito': 6963, 'tipo_interessado': 'Município', 'interessado': 'Novo Repartimento', 'cod_ibge': 1505064, 'uf': 'PA', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000468/2004-89', 'data_protocolo': '2004-09-03T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Saneamento básico', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 13500000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '13/10/2004'}, {'id_pleito': 7636, 'tipo_interessado': 'Município', 'interessado': 'Ramilândia', 'cod_ibge': 4121257, 'uf': 'PR', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000624/2012-11', 'data_protocolo': '2012-04-23T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agência de Fomento do Paraná S/A', 'moeda': 'Real', 'valor': 540000, 'pvl_assoc_divida': 1
# ...

# %%
#conversão para dataframe

data_df = pd.DataFrame(data_json['items'])

data_df
# Out:
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 0          6963        Município    Novo Repartimento   1505064  PA
# 1          7636        Município           Ramilândia   4121257  PR
# 2          7660        Município  Lagoa Bonita do Sul   4311239  RS
# 3         21115        Município             Glorinha   4309050  RS
# 4         14765        Município    São Jorge d'Oeste   4125209  PR
# ...         ...              ...                  ...       ...  ..
# 4995      12902        Município             Alexânia   5200308  GO
# 4996       7486           Estado     Distrito Federal        53  DF
# 4997       7255           Estado       Rio de Janeiro        33  RJ
# 4998      10980        Município              Extrema   3125101  MG
# 4999      10986        Município      Chapadão do Céu   5205471  GO
#
#                    num_pvl                                             status  \
# ...

# %%
#seu código aqui

data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              5000 non-null   int64
#  1   tipo_interessado       5000 non-null   object
#  2   interessado            5000 non-null   object
#  3   cod_ibge               5000 non-null   int64
#  4   uf                     5000 non-null   object
#  5   num_pvl                1956 non-null   object
#  6   status                 5000 non-null   object
#  7   num_processo           4039 non-null   object
#  8   data_protocolo         4039 non-null   object
#  9   tipo_operacao          5000 non-null   object
#  10  finalidade             5000 non-null   object
#  11  tipo_credor            5000 non-null   object
#  12  credor                 5000 non-null   object
#  13  moeda                  5000 non-null   object
# ...

# %%
# Seu código aqui

data_df[data_df['uf'] == 'RJ']
# Out:
#       id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 21        12521        Município     Nova Iguaçu   3303500  RJ
# 55        23148        Município  Rio de Janeiro   3304557  RJ
# 123       21870        Município  Rio de Janeiro   3304557  RJ
# 125        8010        Município         Resende   3304201  RJ
# 174       11692        Município  Rio de Janeiro   3304557  RJ
# ...         ...              ...             ...       ...  ..
# 4752      11415        Município         Niterói   3303302  RJ
# 4812       5645           Estado  Rio de Janeiro        33  RJ
# 4836      60630        Município  Miguel Pereira   3302908  RJ
# 4975      11032        Município      Petrópolis   3303906  RJ
# 4997       7255           Estado  Rio de Janeiro        33  RJ
#
#                    num_pvl                                             status  \
# 21                    None                                           Deferido
# ...

# %%
# 2) Quais são os três status das solicitações mais frequentes na base? Quais são suas frequências?

# Seu código aqui

data_df['status'].value_counts()
# Out:
# Deferido                                                 2797
# Deferido (PVL-IF)                                         920
# Arquivado                                                 401
# Arquivado por decurso de prazo                            275
# Encaminhado à PGFN com manifestação técnica favorável     213
# Regularizado                                              181
# Arquivado a pedido                                         87
# Em retificação pelo interessado                            22
# Indeferido                                                 18
# Em retificação pelo credor (PVL-IF)                        12
# Arquivado a pedido (PVL-IF)                                11
# Cancelado                                                  11
# Pendente de regularização                                   9
# Em retificação pelo credor                                  8
# Arquivado por decurso de prazo (PVL-IF)                     7
# ...

# %%
# 3) Construa uma nova variável que contenha o ano do status. Observe que data_status vem como tipo object no DataFrame. 
     #Dica: você pode usar o método .str para transformar o tipo da variável em string, em seguida um método como slice() ou split().

# Seu código aqui

data_df['data_status'] = pd.to_datetime(data_df['data_status'], format='%d/%m/%Y')
data_df['ano_status'] = data_df['data_status'].dt.year
data_df
# Out:
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 0          6963        Município    Novo Repartimento   1505064  PA
# 1          7636        Município           Ramilândia   4121257  PR
# 2          7660        Município  Lagoa Bonita do Sul   4311239  RS
# 3         21115        Município             Glorinha   4309050  RS
# 4         14765        Município    São Jorge d'Oeste   4125209  PR
# ...         ...              ...                  ...       ...  ..
# 4995      12902        Município             Alexânia   5200308  GO
# 4996       7486           Estado     Distrito Federal        53  DF
# 4997       7255           Estado       Rio de Janeiro        33  RJ
# 4998      10980        Município              Extrema   3125101  MG
# 4999      10986        Município      Chapadão do Céu   5205471  GO
#
#                    num_pvl                                             status  \
# ...

# %%
# 4) Indique a frequência de cada ano do campo construído no item (3).

# seu código aqui

data_df['ano_status'].value_counts()
# Out:
# 2008    435
# 2019    394
# 2007    310
# 2018    305
# 2014    289
# 2010    279
# 2012    277
# 2006    230
# 2017    230
# 2016    229
# 2013    223
# 2011    212
# 2022    209
# 2009    204
# 2020    200
# 2023    197
# 2021    181
# 2004    180
# 2015    156
# 2002    119
# 2003     93
# 2005     48
# Name: ano_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado ('Estado'ou Município), e que
   #devolve os dados da consulta no formato DataFrame.

#Seu código aqui

def consulta(uf, tipo_interessado):
    consulta_df = data_df[(data_df['tipo_interessado'] == tipo_interessado) & (data_df['uf'] == uf)]
    consulta_df = pd.DataFrame(consulta_df)
    return consulta_df
    
consulta(uf='PA', tipo_interessado='Estado')
# Out:
#       id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 12         6587           Estado        Pará        15  PA
# 186       11660           Estado        Pará        15  PA
# 854        9542           Estado        Pará        15  PA
# 1180       6292           Estado        Pará        15  PA
# 1297      12083           Estado        Pará        15  PA
# 1392       9658           Estado        Pará        15  PA
# 2609       5532           Estado        Pará        15  PA
# 2736       5603           Estado        Pará        15  PA
# 3011      23726           Estado        Pará        15  PA
# 3032       5598           Estado        Pará        15  PA
# 4308      53829           Estado        Pará        15  PA
# 4620      65881           Estado        Pará        15  PA
# 4792      11507           Estado        Pará        15  PA
#
#                    num_pvl                                             status  \
# ...

# %%
# 2) Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com status em 'Arquivado por decurso de prazo' 
    #estão registradas?

# Seu código aqui

minas = consulta(uf = 'MG', tipo_interessado = 'Estado')

minas[minas['status'] == 'Arquivado por decurso de prazo'].value_counts()
# Out:
# Series([], dtype: int64)

# %%
# 3) Qual é o município da Bahia com mais solicitações deferidas?

# Seu código aqui

bahia = consulta(uf = 'BA', tipo_interessado = 'Município')

bahia[bahia['status'] == 'Deferido'].value_counts('interessado')
# Out:
# interessado
# Luís Eduardo Magalhães    4
# Abaíra                    3
# Vitória da Conquista      3
# Teixeira de Freitas       3
# Mucuri                    3
#                          ..
# Mansidão                  1
# Mata de São João          1
# Mucugê                    1
# Caculé                    1
# Xique-Xique               1
# Length: 82, dtype: int64

# %%
# 4) Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'.

# Seu código aqui

bahia = consulta(uf = 'BA', tipo_interessado = 'Estado')

bahia.to_csv('C:/Users/adilt/Ebac/Notebooks/Cientista de dados/bahia.csv')
